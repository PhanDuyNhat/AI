# %% [markdown]
# <a href="https://colab.research.google.com/github/PhanDuyNhat/AI/blob/Code_AI/week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy  as np
import matplotlib.pyplot as plt
url = 'mtcars.csv'
data = pd.read_csv(url)
data.hist()
plt.show

correlation = data.corr()
print(correlation)

import seaborn as sns
sns.heatmap(correlation, annot = True)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
# <AxesSubplot:title={'center':'wt'}>

# %%
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
from sklearn import linear_model 
model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['wt']),y=data['mpg'])
print(model.intercept_)
print(model.coef_)
model.score(X=pd.DataFrame(data['wt']),y=data['mpg'])
# Out:
# 37.28512616734204
# [-5.34447157]
# 0.7528327936582646

# %%
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black',xlim=(0,7))
y_pred=model.predict(X=pd.DataFrame(data['wt']))
plt.plot(data['wt'],y_pred,color='red')

# %%
from sklearn import linear_model 
model = linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh',model.intercept_)
print('confient cua mo hinh ',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
# Out:
# intercept cua mo hinh 49.93081094945181
# confient cua mo hinh  [-13.38033708   1.17108689]
# do chinh xac cua mo hinh 0.8190613581384094

# %%
import numpy as np

data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black')
range= np.arange(0,6,0.1)
predictor = pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=predictor)
plt.plot(range,y_pred,color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model 
model = linear_model.LinearRegression()
X=pd.DataFrame([data['wt'],data['wt']**2,data['wt']**3,data['wt']**4,data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('intercept cua mo hinh',model.intercept_)
print('confient cua mo hinh ',model.coef_)
print('do chinh xac cua mo hinh',model.score(X,y=data['mpg']))
# Out:
# intercept cua mo hinh -87.71816314301019
# confient cua mo hinh  [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# do chinh xac cua mo hinh 0.8251088272653132

# %%
import numpy as np
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
range = np.arange(0,6,0.1)
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**5]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import linear_model 
model=linear_model.LinearRegression()
data.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9,9), color = 'black', xlim = (0,7))
model.fit(X=data.loc[:,['wt','hp']],y=data['mpg'])

print(model.intercept_)
print(model.coef_)
print(model.score(X=data.loc[:,['wt','hp']],y=data['mpg']))
# Out:
# 37.227270116447215
# [-3.87783074 -0.03177295]
# 0.8267854518827914

# %%
import pandas as pd 
import numpy  as np
import matplotlib.pyplot as plt
url2 = 'Salary_Data.csv'
data2 = pd.read_csv(url2)
data2.hist()

plt.show
correlation2 = data2.corr()
print(correlation2)

import seaborn as sns
sns.heatmap(correlation2, annot = True)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000
# <AxesSubplot:title={'center':'Salary'}>

# %%
data2.plot(kind = 'scatter', x = 'Salary', y = 'YearsExperience', figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='YearsExperience'>

# %%
from sklearn import linear_model 
model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['Salary']),y=data['YearsExperience'])
print(model.intercept_)
print(model.coef_)
model.score(X=pd.DataFrame(data['Salary']),y=data['YearsExperience'])
# Out:
# -2.3831605648243537
# [0.00010127]
# 0.9569566641435086

# %%
data2.plot(kind = 'scatter', x = 'Salary', y = 'YearsExperience', figsize = (9,9), color = 'black')
y_pred=model.predict(X=pd.DataFrame(data['Salary']))
plt.plot(data['Salary'],y_pred,color='red')

# %%
import pandas as pd 
import numpy  as np
import matplotlib.pyplot as plt
url3 = '50_Startups.csv'
data3 = pd.read_csv(url3)
data3.hist()
plt.show

correlation3 = data3.corr()
print(correlation)

import seaborn as sns
sns.heatmap(correlation3, annot = True)
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000
# <AxesSubplot:title={'center':'Profit'}>

# %%
data3.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='R&D Spend', ylabel='Profit'>

# %%
from sklearn import linear_model 
model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['R&D Spend']),y=data['Profit'])
print(model.intercept_)
print(model.coef_)
model.score(X=pd.DataFrame(data['R&D Spend']),y=data['Profit'])
# Out:
# 49032.89914125215
# [0.85429137]
# 0.9465353160804393

# %%
data3.plot(kind = 'scatter', x = 'R&D Spend', y = 'Profit', figsize = (9,9), color = 'black')
y_pred=model.predict(X=pd.DataFrame(data['R&D Spend']))
plt.plot(data['R&D Spend'],y_pred,color='red')
